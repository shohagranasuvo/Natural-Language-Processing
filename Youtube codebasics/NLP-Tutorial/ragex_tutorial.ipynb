# %%
import re

# %%
chat1 = 'codebasics: you ask lot of questions 😡 1235678912, abc@xyz.com ,01985446107 ,(123)-567-8912'
chat2 = 'codebasics: here it is: (123)-567-8912, abc@xyz.com'
chat3 = 'codebasics: yes, phone: 1235678912 email: abc@xyz.com'
chat4 = 'shohag : My order 4123456789 ,My order number #9832343284 ,it unsuccessfull'

# %%
pattern =r'\d{10,11}|\(\d{3}\)-\d{3}-\d{4}|[a-zA-Z0-9._%+-]+@[a-zA-Z0-9.-]+\.com'
#pattern =r'\d{10}'
match = re.findall(pattern ,chat1)
email =match[1]
email
# Out:
# 'abc@xyz.com'

# %%
pattern2 =r'order[^\d]*(\d*)'
matches = re.findall(pattern,chat4)
order =matches[0]
order
# Out:
# '4123456789'
