# %%
import spacy

# %%
nlp =spacy.blank("en")
doc =nlp("Dr. Strange loves pav bhaji of mumbai. Hulkk loves chat of delhi .")
for token in doc:
    print(token)
# Out:
# Dr.
# Strange
# loves
# pav
# bhaji
# of
# mumbai
# .
# Hulkk
# loves
# chat
# of
# delhi
# .

# %%
doc[6:10]
# Out:
# mumbai. Hulkk loves

# %%
doc =nlp('''"Let's go to N.Y.!"''')
for token in doc:
    print(token)
# Out:
# "
# Let
# 's
# go
# to
# N.Y.
# !
# "

# %%
type(nlp)
# Out:
# spacy.lang.en.English

# %%
type(doc)
# Out:
# spacy.tokens.doc.Doc

# %%
span = doc[2:4]
type(span)
# Out:
# spacy.tokens.span.Span

# %%
index0=doc[0]
index0
# Out:
# "

# %%
index0.is_punct
# Out:
# True

# %%
doc =nlp('''" twenty.com boy listen -- Let's go to N.Y.!"''')
index1 =doc[1]
index1
# Out:
# twenty.com

# %%
index1.like_num
# Out:
# False

# %%
 index1.like_email
# Out:
# False

# %%
index1.like_url
# Out:
# True

# %%
with open("info.txt") as f:
   text =f.readlines()
text
# Out:
# ['Student Name: Ayesha Rahman\n',
#  'Birthday: 2003-01-15\n',
#  'Email: ayesha.rahman@google.com\n',
#  '\n',
#  'Student Name: Fahim Ahmed\n',
#  'Birthday: 2002-03-28\n',
#  'Email: fahim.ahmed@google.com\n',
#  '\n',
#  'Student Name: Nusrat Jahan\n',
#  'Birthday: 2001-07-12\n',
#  'Email: nusrat.jahan@google.com\n',
#  '\n',
#  'Student Name: Tanvir Hasan\n',
#  'Birthday: 2002-11-05\n',
#  'Email: tanvir.hasan@google.com\n',
#  '\n',
#  'Student Name: Sadia Islam\n',
#  'Birthday: 2003-02-20\n',
#  'Email: sadia.islam@google.com\n',
#  '\n',
#  'Student Name: Mehedi Hasan\n',
#  'Birthday: 2001-09-17\n',
#  'Email: mehedi.hasan@google.com\n',
#  '\n',
#  'Student Name: Farzana Akter\n',
#  'Birthday: 2002-12-09\n',
#  'Email: farzana.akter@google.com\n',
#  '\n',
#  'Student Name: Rakib Hossain\n',
#  'Birthday: 2003-05-03\n',
#  'Email: rakib.hossain@google.com\n',
#  '\n',
#  'Student Name: Tania Sultana\n',
#  'Birthday: 2001-10-22\n',
# ...

# %%
text =' '.join(text)
text
# Out:
# 'Student Name: Ayesha Rahman\n Birthday: 2003-01-15\n Email: ayesha.rahman@google.com\n \n Student Name: Fahim Ahmed\n Birthday: 2002-03-28\n Email: fahim.ahmed@google.com\n \n Student Name: Nusrat Jahan\n Birthday: 2001-07-12\n Email: nusrat.jahan@google.com\n \n Student Name: Tanvir Hasan\n Birthday: 2002-11-05\n Email: tanvir.hasan@google.com\n \n Student Name: Sadia Islam\n Birthday: 2003-02-20\n Email: sadia.islam@google.com\n \n Student Name: Mehedi Hasan\n Birthday: 2001-09-17\n Email: mehedi.hasan@google.com\n \n Student Name: Farzana Akter\n Birthday: 2002-12-09\n Email: farzana.akter@google.com\n \n Student Name: Rakib Hossain\n Birthday: 2003-05-03\n Email: rakib.hossain@google.com\n \n Student Name: Tania Sultana\n Birthday: 2001-10-22\n Email: tania.sultana@google.com\n \n Student Name: Imran Kabir\n Birthday: 2002-06-14\n Email: imran.kabir@google.com\n \n Student Name: Rifat Chowdhury\n Birthday: 2003-08-31\n Email: rifat.chowdhury@google.com\n \n Student Name: Priya D
# ...

# %%
doc =nlp(text)
email  = []
for token in doc :
    if(token.like_email):
        print(token)
        email.append(token.text)
# Out:
# ayesha.rahman@google.com
# fahim.ahmed@google.com
# nusrat.jahan@google.com
# tanvir.hasan@google.com
# sadia.islam@google.com
# mehedi.hasan@google.com
# farzana.akter@google.com
# rakib.hossain@google.com
# tania.sultana@google.com
# imran.kabir@google.com
# rifat.chowdhury@google.com
# priya.das@google.com
# arif.hossain@google.com
# mahi.akter@google.com
# samiul.islam@google.com

# %%
email
# Out:
# ['ayesha.rahman@google.com',
#  'fahim.ahmed@google.com',
#  'nusrat.jahan@google.com',
#  'tanvir.hasan@google.com',
#  'sadia.islam@google.com',
#  'mehedi.hasan@google.com',
#  'farzana.akter@google.com',
#  'rakib.hossain@google.com',
#  'tania.sultana@google.com',
#  'imran.kabir@google.com',
#  'rifat.chowdhury@google.com',
#  'priya.das@google.com',
#  'arif.hossain@google.com',
#  'mahi.akter@google.com',
#  'samiul.islam@google.com']

# %%
nlp =spacy.blank("bn")

with open("bangla.txt", "r", encoding="utf-8") as f:
  text =f.read() ;

text =nlp(text)
for word in text :
    print(word)
# Out:
# আজকের
# আবহাওয়া
# খুব
# সুন্দর
# ।
# সকালে
# হালকা
# বৃষ্টি
# হয়েছে
# ।
# এরপর
# সূর্য
# উঠেছে
# এবং
# চারদিকে
# মনোরম
# পরিবেশ
# তৈরি
# হয়েছে
# ।
# অনেক
# মানুষ
# পার্কে
# হাঁটতে
# গিয়েছে
# ।
# কিছু
# শিশু
# ফুটবল
# খেলছে
# ,
# আবার
# কেউ
# বই
# পড়ছে
# ।
# সন্ধ্যায়
# সবাই
# পরিবারের
# সঙ্গে
# সময়
# কাটাবে
# ।

# %%
from spacy.symbols import ORTH
nlp.tokenizer.add_special_case("gimme",[
    {ORTH:"gim"},
    {ORTH:"me"}
])
doc =nlp("gimme a cup of tea!")
tokens= [token.text for token in doc ]
tokens
# Out:
# ['gim', 'me', 'a', 'cup', 'of', 'tea', '!']

# %%
nlp.add_pipe('sentencizer')

# %%
doc=nlp("Dr. Strange loves pav bhaji of mumbai. Hulkk loves chat of delhi .")
for sentence in doc.sents :
    print(sentence)
# Out:
# Dr.
# Strange loves pav bhaji of mumbai.
# Hulkk loves chat of delhi .
