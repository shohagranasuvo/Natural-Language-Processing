# %%
import spacy

# %%
nlp=spacy.load("en_core_web_sm")

# %%
nlp.pipeline
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x7bc98df53580>),
#  ('tagger', <spacy.pipeline.tagger.Tagger at 0x7bc98df536f0>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x7bc98df673e0>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x7bc98e4d1fd0>),
#  ('lemmatizer',
#   <spacy.lang.en.lemmatizer.EnglishLemmatizer at 0x7bc98e4d2120>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x7bc98df67760>)]

# %%
doc = nlp("Dr. Strange loves pav bhaji of mumbai as it costs only 2$ per plate.")

for token in doc:
    print(token ," | ",token.pos_ ," | " ,token.lemma_)
# Out:
# Dr.  |  PROPN  |  Dr.
# Strange  |  PROPN  |  Strange
# loves  |  VERB  |  love
# pav  |  NOUN  |  pav
# bhaji  |  NOUN  |  bhaji
# of  |  ADP  |  of
# mumbai  |  NOUN  |  mumbai
# as  |  SCONJ  |  as
# it  |  PRON  |  it
# costs  |  VERB  |  cost
# only  |  ADV  |  only
# 2  |  NUM  |  2
# $  |  NUM  |  $
# per  |  ADP  |  per
# plate  |  NOUN  |  plate
# .  |  PUNCT  |  .

# %%
from spacy import displacy
displacy.render(doc ,style ="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Dr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Strange
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  loves pav bhaji of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mumbai
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  as it costs
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     only 2$
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  per plate.</div></span>

# %%
nlp_source = spacy.load("en_core_web_sm")
nlp=spacy.blank("en")
nlp.add_pipe("ner",source =nlp_source )
nlp.pipe_names
# Out:
# ['ner']

# %%
doc = nlp("Dr. Strange loves pav bhaji of mumbai as it costs only 2$ per plate.")

for ent in doc.ents:
    print(ent.text," | ",ent.label_ ," | " , spacy.explain(ent.label_))
# Out:
# Strange  |  PERSON  |  People, including fictional
# mumbai  |  GPE  |  Countries, cities, states
# only 2$  |  MONEY  |  Monetary values, including unit

# %%
doc = nlp("Elon Musk donated $100 to AIUB in Dhaka on Monday.")

for ent in doc.ents:
    print(ent.text," | ",ent.label_ ," | " , spacy.explain(ent.label_))
# Out:
# 100  |  MONEY  |  Monetary values, including unit
# Dhaka  |  GPE  |  Countries, cities, states
# Monday  |  DATE  |  Absolute or relative dates or periods
